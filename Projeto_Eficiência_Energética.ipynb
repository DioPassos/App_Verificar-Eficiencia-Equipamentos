# %% [markdown]
# # <font color='Blue'>**Integrante**</font>
#
# ### <font color='black'>**-Dioeliton Passos** </font>
# ### <font color='Red'> Projeto Eficiência Energética </font>

# %% [markdown]
# # 1° Definir problema negócio,qual a dor.
#
# -Nosso Foco: Fazer uso de algoritimos de Machine learning nos diversos processos fabris que possam nos auxilar nas tomadas de decisão referente a a eficiencia dos diversos tipos de enérgia utilizado na Planta

# %% [markdown]
# ##### **Fonte dos Dados**

# %% [markdown]
# ###### **Arquitetura dos Dados** (AD)
#
# * **Equipamento**  : Descrição Equipamento
# * **Velocidade**        : Velocidade Equipamento
# * **Corrente**: Corrente Elétrica
# * **Temperatura** : Valor Temperatura Equipamento
# * **Eficiencia**       : Descrição /Clssificação conforme parametros

# %% [markdown]
# # 2° Análise Exploratória dos Dados

# %%
# Importando Bibliotecas Essenciais
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
# %matplotlib inline

# %%
# Se conectando com os dados - Nesse caso, a Fonte de Dados é um Arquivo
dataset = pd.read_csv('/content/dados_eficiencia.csv')

# %%
# Imprime na Tela os primeiros registros
dataset.head()
# Out:
#    Equipamento  Potencia  Velocidade  Temperatura  Corrente       Eficiencia
# 0            0       5.1         3.5          1.4       0.2  Muito Eficiente
# 1            1       4.9         3.0          1.4       0.2  Muito Eficiente
# 2            2       4.7         3.2          1.3       0.2  Muito Eficiente
# 3            3       4.6         3.1          1.5       0.2  Muito Eficiente
# 4            4       5.0         3.6          1.4       0.2  Muito Eficiente

# %%
# Informações do Dataset - Tipo das Variáveis, Quantidade de linhas (registros) e colunas (variáveis/features)
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Equipamento  150 non-null    int64
#  1   Potencia     150 non-null    float64
#  2   Velocidade   150 non-null    float64
#  3   Temperatura  150 non-null    float64
#  4   Corrente     150 non-null    float64
#  5   Eficiencia   150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
#Verifica as dimensões do dataset (antes de vírgula são linhas    ,     depois da vírgula são colunas)
dataset.shape
# Out:
# (150, 6)

# %%
# Cria uma função para imprimir na tela o resultado da função SHAPE
print(f"Dataset tem {dataset.shape[0]} linhas e {dataset.shape[1]} colunas.")
# Out:
# Dataset tem 150 linhas e 6 colunas.

# %%
#Estatísticas descritivas das variáveis numéricas
dataset.describe()
# Out:
#        Equipamento    Potencia  Velocidade  Temperatura    Corrente
# count   150.000000  150.000000  150.000000   150.000000  150.000000
# mean     74.500000    5.843333    3.054000     3.758667    1.198667
# std      43.445368    0.828066    0.433594     1.764420    0.763161
# min       0.000000    4.300000    2.000000     1.000000    0.100000
# 25%      37.250000    5.100000    2.800000     1.600000    0.300000
# 50%      74.500000    5.800000    3.000000     4.350000    1.300000
# 75%     111.750000    6.400000    3.300000     5.100000    1.800000
# max     149.000000    7.900000    4.400000     6.900000    2.500000

# %%
# Tabela de Frequência da Variável "risco" - Nossa Classe ou Label ou Target
dataset['Eficiencia'].value_counts()
# Out:
# Ineficiente        50
# Eficiente          50
# Muito Eficiente    50
# Name: Eficiencia, dtype: int64

# %%
# Cria um gráfico de barras da variável Target
sns.countplot(dataset['Eficiencia'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Check for missing values
dataset.isna().sum()
# Out:
# Equipamento    0
# Potencia       0
# Velocidade     0
# Temperatura    0
# Corrente       0
# Eficiencia     0
# dtype: int64

# %%
#Eliminar a coluna de identificação, pois ela não é variável explicativa, é somente a identificação do cliente7
dataset = dataset.drop(columns='Equipamento')

# %%
#Printa o dataset na tela
dataset
# Out:
#      Potencia  Velocidade  Temperatura  Corrente       Eficiencia
# 0         5.1         3.5          1.4       0.2  Muito Eficiente
# 1         4.9         3.0          1.4       0.2  Muito Eficiente
# 2         4.7         3.2          1.3       0.2  Muito Eficiente
# 3         4.6         3.1          1.5       0.2  Muito Eficiente
# 4         5.0         3.6          1.4       0.2  Muito Eficiente
# ..        ...         ...          ...       ...              ...
# 145       6.7         3.0          5.2       2.3      Ineficiente
# 146       6.3         2.5          5.0       1.9      Ineficiente
# 147       6.5         3.0          5.2       2.0      Ineficiente
# 148       6.2         3.4          5.4       2.3      Ineficiente
# 149       5.9         3.0          5.1       1.8      Ineficiente
#
# [150 rows x 5 columns]

# %%
# Cria um gráfico tipo box and whisker plots (o famoso boxplot)
from matplotlib import pyplot
dataset.plot(kind='box', subplots=True, layout=(2,2), sharex=False, sharey=False)
pyplot.show()

# %%
#cria um gráfico conhecido como histohrama
dataset.hist()
plt.show()

# %%
# Criação do Gráfico de dispersão (scatter) conhecido como pairplot
sns.pairplot(dataset, hue='Eficiencia', kind="reg") # kind=reg é a reta de regressão

# %%
# Criação do Gráfico de dispersão sem agregar pelo TARGET
sns.pairplot(dataset,kind="reg")

# %% [markdown]
# # 3° Pré-Processamento dos Dados

# %%
#3 Separando as Variáveis de Entrada e Saída do Modelo
X = dataset.iloc[:,:-1].values  #variáveis independentes
y = dataset.iloc[:,-1].values  #Target/labe/class/vairável dependente

# %%
#Print das variáveis X e Y
print("\nVariáveis de Entrada da avaliação:\n\n", X[:3])
print("\nEficiencia - Variável a ser Predita :\n\n", y[:3])
# Out:
# Variáveis de Entrada da avaliação:
#
#  [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]]
#
# Eficiencia - Variável a ser Predita :
#
#  ['Muito Eficiente' 'Muito Eficiente' 'Muito Eficiente']

# %%
X
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.5, 4.2, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5. , 3.2, 1.2, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [4.4, 3. , 1.3, 0.2],
#        [5.1, 3.4, 1.5, 0.2],
#        [5. , 3.5, 1.3, 0.3],
#        [4.5, 2.3, 1.3, 0.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [5. , 3.5, 1.6, 0.6],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.8, 3. , 1.4, 0.3],
#        [5.1, 3.8, 1.6, 0.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5. , 3.3, 1.4, 0.2],
#        [7. , 3.2, 4.7, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.5, 2.3, 4. , 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [4.9, 2.4, 3.3, 1. ],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [5. , 2. , 3.5, 1. ],
#        [5.9, 3. , 4.2, 1.5],
#        [6. , 2.2, 4. , 1. ],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.6, 3. , 4.5, 1.5],
#        [5.8, 2.7, 4.1, 1. ],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.1, 2.8, 4. , 1.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.4, 2.9, 4.3, 1.3],
#        [6.6, 3. , 4.4, 1.4],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.7, 3. , 5. , 1.7],
#        [6. , 2.9, 4.5, 1.5],
#        [5.7, 2.6, 3.5, 1. ],
#        [5.5, 2.4, 3.8, 1.1],
#        [5.5, 2.4, 3.7, 1. ],
#        [5.8, 2.7, 3.9, 1.2],
#        [6. , 2.7, 5.1, 1.6],
#        [5.4, 3. , 4.5, 1.5],
#        [6. , 3.4, 4.5, 1.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.6, 3. , 4.1, 1.3],
#        [5.5, 2.5, 4. , 1.3],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.1, 3. , 4.6, 1.4],
#        [5.8, 2.6, 4. , 1.2],
#        [5. , 2.3, 3.3, 1. ],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.7, 3. , 4.2, 1.2],
#        [5.7, 2.9, 4.2, 1.3],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.1, 2.5, 3. , 1.1],
#        [5.7, 2.8, 4.1, 1.3],
#        [6.3, 3.3, 6. , 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3. , 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3. , 5.8, 2.2],
#        [7.6, 3. , 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.8, 3. , 5.5, 2.1],
#        [5.7, 2.5, 5. , 2. ],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.5, 3. , 5.5, 1.8],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [6. , 2.2, 5. , 1.5],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.8, 4.9, 2. ],
#        [7.7, 2.8, 6.7, 2. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.7, 3.3, 5.7, 2.1],
#        [7.2, 3.2, 6. , 1.8],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.1, 3. , 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.1],
#        [7.2, 3. , 5.8, 1.6],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.1, 2.6, 5.6, 1.4],
#        [7.7, 3. , 6.1, 2.3],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.4, 3.1, 5.5, 1.8],
#        [6. , 3. , 4.8, 1.8],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.7, 3.1, 5.6, 2.4],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.7, 3. , 5.2, 2.3],
#        [6.3, 2.5, 5. , 1.9],
#        [6.5, 3. , 5.2, 2. ],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.9, 3. , 5.1, 1.8]])

# %%
y
# Out:
# array(['Muito Eficiente', 'Muito Eficiente', 'Muito Eficiente',
#        'Muito Eficiente', 'Muito Eficiente', 'Muito Eficiente',
#        'Muito Eficiente', 'Muito Eficiente', 'Muito Eficiente',
#        'Muito Eficiente', 'Muito Eficiente', 'Muito Eficiente',
#        'Muito Eficiente', 'Muito Eficiente', 'Muito Eficiente',
#        'Muito Eficiente', 'Muito Eficiente', 'Muito Eficiente',
#        'Muito Eficiente', 'Muito Eficiente', 'Muito Eficiente',
#        'Muito Eficiente', 'Muito Eficiente', 'Muito Eficiente',
#        'Muito Eficiente', 'Muito Eficiente', 'Muito Eficiente',
#        'Muito Eficiente', 'Muito Eficiente', 'Muito Eficiente',
#        'Muito Eficiente', 'Muito Eficiente', 'Muito Eficiente',
#        'Muito Eficiente', 'Muito Eficiente', 'Muito Eficiente',
#        'Muito Eficiente', 'Muito Eficiente', 'Muito Eficiente',
#        'Muito Eficiente', 'Muito Eficiente', 'Muito Eficiente',
#        'Muito Eficiente', 'Muito Eficiente', 'Muito Eficiente',
#        'Muito Eficiente', 'Muito Eficiente', 'Muito Eficiente',
#        'Muito Eficiente', 'Muito Eficiente', 'Eficiente', 'Eficiente',
#        'Eficiente', 'Eficiente', 'Eficiente', 'Eficiente', 'Eficiente',
#        'Eficiente', 'Eficiente', 'Eficiente', 'Eficiente', 'Eficiente',
#        'Eficiente', 'Eficiente', 'Eficiente', 'Eficiente', 'Eficiente',
#        'Eficiente', 'Eficiente', 'Eficiente', 'Eficiente', 'Eficiente',
#        'Eficiente', 'Eficiente', 'Eficiente', 'Eficiente', 'Eficiente',
#        'Eficiente', 'Eficiente', 'Eficiente', 'Eficiente', 'Eficiente',
#        'Eficiente', 'Eficiente', 'Eficiente', 'Eficiente', 'Eficiente',
#        'Eficiente', 'Eficiente', 'Eficiente', 'Eficiente', 'Eficiente',
#        'Eficiente', 'Eficiente', 'Eficiente', 'Eficiente', 'Eficiente',
#        'Eficiente', 'Eficiente', 'Eficiente', 'Ineficiente',
#        'Ineficiente', 'Ineficiente', 'Ineficiente', 'Ineficiente',
#        'Ineficiente', 'Ineficiente', 'Ineficiente', 'Ineficiente',
#        'Ineficiente', 'Ineficiente', 'Ineficiente', 'Ineficiente',
#        'Ineficiente', 'Ineficiente', 'Ineficiente', 'Ineficiente',
#        'Ineficiente', 'Ineficiente', 'Ineficiente', 'Ineficiente',
#        'Ineficiente', 'Ineficiente', 'Ineficiente', 'Ineficiente',
#        'Ineficiente', 'Ineficiente', 'Ineficiente', 'Ineficiente',
#        'Ineficiente', 'Ineficiente', 'Ineficiente', 'Ineficiente',
#        'Ineficiente', 'Ineficiente', 'Ineficiente', 'Ineficiente',
#        'Ineficiente', 'Ineficiente', 'Ineficiente', 'Ineficiente',
#        'Ineficiente', 'Ineficiente', 'Ineficiente', 'Ineficiente',
#        'Ineficiente', 'Ineficiente', 'Ineficiente', 'Ineficiente',
#        'Ineficiente'], dtype=object)

# %% [markdown]
# ### Separando os dados entre Treino e Teste

# %%
#Divide o dataset em Train and Test 
X_train, X_test, y_train, y_test = train_test_split(X ,y, test_size=0.2, random_state = 7)

# %%
print("Dados de Treino :\n----------------\n")
print("X = \n", X_train[:2])
print("y = \n", y_train[:2])

print("\n\nDados de Teste :\n----------------\n")
print("X = \n",X_test[:2])
print("y = \n", y_test[:2])
# Out:
# Dados de Treino :
# ----------------
#
# X =
#  [[6.2 2.8 4.8 1.8]
#  [5.7 2.6 3.5 1. ]]
# y =
#  ['Ineficiente' 'Eficiente']
#
#
# Dados de Teste :
# ----------------
#
# X =
#  [[5.9 3.  5.1 1.8]
#  [5.4 3.  4.5 1.5]]
# y =
#  ['Ineficiente' 'Eficiente']

# %%
print(f"Shape dos dados de treino é {X_train.shape}")
print(f"Shape dos dados de teste é {X_test.shape}")
# Out:
# Shape dos dados de treino é (120, 4)
# Shape dos dados de teste é (30, 4)

# %% [markdown]
# ### Padronizando as Features - As variáveis explicativas (variáveis de entrada)

# %%
#Redimensionando os dados - PADRONIZAÇÂO - Feature scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test) 

print("\n--------------------------------\nDataset depois da padronização:\n--------------------------------\n", )

print("\nX_train :\n", X_train[:5])
print("-------------------------")
print("\nX_test :\n", X_test[:5])
# Out:
# --------------------------------
# Dataset depois da padronização:
# --------------------------------
#
#
# X_train :
#  [[ 0.43325894 -0.59653573  0.62601116  0.82081788]
#  [-0.15754871 -1.05688485 -0.09737951 -0.21464226]
#  [-1.45732553  1.24486074 -1.48851543 -1.2501024 ]
#  [ 1.26038965  0.09398794  0.95988378  1.20911544]
#  [ 0.669582   -0.36636117  0.34778398  0.17365529]]
# -------------------------
#
# X_test :
#  [[ 0.07877435 -0.13618661  0.79294747  0.82081788]
#  [-0.51203329 -0.13618661  0.45907485  0.43252033]
#  [-0.98467941  1.01468618 -1.32157912 -1.12066988]
#  [-0.27571024 -0.13618661  0.45907485  0.43252033]
#  [-1.10284094 -1.28705941  0.45907485  0.69138537]]

# %% [markdown]
# # <font color='Black'> **Construíndo Máquinas Preditivas** </font>

# %% [markdown]
# # 4° Construindo a Máquina Preditiva

# %% [markdown]
# ### 1° Versão da Máquina Preditiva: Criando um **baseline**
#
# Aqui nós vamos criar a primeira versão da Máquina Preditiva. Depois, vamos buscar formas de melhorar a assertividade do modelo.

# %%
# Importando a Biblioteca KNN
from sklearn.neighbors import KNeighborsClassifier
Maquina_Preditiva = KNeighborsClassifier(n_neighbors=30) #[1,10,30,50]

# %%
#Treinando a Máquina preditiva com os dados de treino
Maquina_Preditiva = Maquina_Preditiva.fit(X_train,y_train)

# %%
#Fazendo novas Previsões com os dados de teste
y_pred = Maquina_Preditiva.predict(X_test)


print("\n---------------------------\n")
print("Valores Reais com dados de teste :\n",y_test)

print("\n---------------------------\n")
print("Valores Preditos com a Máquina Preditiva com dados de Teste :\n",y_pred)
# Out:
# ---------------------------
#
# Valores Reais com dados de teste :
#  ['Ineficiente' 'Eficiente' 'Muito Eficiente' 'Eficiente' 'Ineficiente'
#  'Muito Eficiente' 'Eficiente' 'Eficiente' 'Muito Eficiente' 'Eficiente'
#  'Eficiente' 'Eficiente' 'Muito Eficiente' 'Ineficiente' 'Muito Eficiente'
#  'Eficiente' 'Ineficiente' 'Ineficiente' 'Muito Eficiente'
#  'Muito Eficiente' 'Eficiente' 'Ineficiente' 'Eficiente' 'Ineficiente'
#  'Ineficiente' 'Ineficiente' 'Eficiente' 'Eficiente' 'Ineficiente'
#  'Ineficiente']
#
# ---------------------------
#
# Valores Preditos com a Máquina Preditiva com dados de Teste :
#  ['Ineficiente' 'Eficiente' 'Muito Eficiente' 'Eficiente' 'Eficiente'
#  'Muito Eficiente' 'Ineficiente' 'Eficiente' 'Muito Eficiente' 'Eficiente'
#  'Ineficiente' 'Eficiente' 'Muito Eficiente' 'Ineficiente'
#  'Muito Eficiente' 'Eficiente' 'Ineficiente' 'Ineficiente'
#  'Muito Eficiente' 'Muito Eficiente' 'Eficiente' 'Ineficiente' 'Eficiente'
#  'Eficiente' 'Ineficiente' 'Eficiente' 'Eficiente' 'Eficiente'
#  'Ineficiente' 'Ineficiente']

# %%
#Função que mostra os hyperparâmetros utilizados na construção da Máquina Preditiva 
Maquina_Preditiva.get_params
# Out:
# <bound method BaseEstimator.get_params of KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=30, p=2,
#                      weights='uniform')>

# %% [markdown]
# #5° Avaliando a Máquina Preditiva

# %%
# Calculando a Acurácia
from sklearn import metrics
print("Acurácia da Máquina = ", metrics.accuracy_score(y_test, y_pred)*100)
# Out:
# Acurácia da Máquina =  83.33333333333334

# %%
# Comparando Real e Predito com dados de Teste
print("\nReal vs Predito \n------------------------------\n")
error_df = pd.DataFrame({"Real" : y_test,
                         "Predito" : y_pred})

error_df.head(5)
# Out:
# Real vs Predito
# ------------------------------
#               Real          Predito
# 0      Ineficiente      Ineficiente
# 1        Eficiente        Eficiente
# 2  Muito Eficiente  Muito Eficiente
# 3        Eficiente        Eficiente
# 4      Ineficiente        Eficiente

# %%
#Usando a confusion matrix  e o classification report para avaliar a acurácia e demais indicadores
from sklearn.metrics import confusion_matrix, classification_report
from sklearn import metrics

print("Acurácia da Máquina = ", metrics.accuracy_score(y_test, y_pred)*100)
cm = confusion_matrix(y_test,y_pred)
cr = classification_report(y_test, y_pred)
print(cm)
print(cr)
# Out:
# Acurácia da Máquina =  83.33333333333334
# [[10  2  0]
#  [ 3  8  0]
#  [ 0  0  7]]
#                  precision    recall  f1-score   support
#
#       Eficiente       0.77      0.83      0.80        12
#     Ineficiente       0.80      0.73      0.76        11
# Muito Eficiente       1.00      1.00      1.00         7
#
#        accuracy                           0.83        30
#       macro avg       0.86      0.85      0.85        30
#    weighted avg       0.83      0.83      0.83        30

# %% [markdown]
# ### 2° Versão da Máquina Preditiva: Máquina Definitiva

# %%
# Importando a Biblioteca do SVM
from sklearn.svm import SVC
classifier = SVC(kernel='linear',             # ['linear', 'rbf']
                 gamma= 1e-5  ,               # [1e-1, 1e-2, 1e-3, 1e-5]
                 C=10,                        # [10.0, 100.0, 1000.0, 10000.0]
                 random_state=7)

# %%
#Treinando a Máquina com o SVC
classifier.fit(X_train,y_train)
# Out:
# SVC(C=10, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=1e-05, kernel='linear',
#     max_iter=-1, probability=False, random_state=7, shrinking=True, tol=0.001,
#     verbose=False)

# %%
#Fazendo novas previsões com os dados de teste
y_pred = classifier.predict(X_test)

print("\n---------------------------\n")
print("Predicted Values for Test Set :\n",y_pred)
print("\n---------------------------\n")
print("Actual Values for Test Set :\n",y_test)
# Out:
# ---------------------------
#
# Predicted Values for Test Set :
#  ['Ineficiente' 'Eficiente' 'Muito Eficiente' 'Eficiente' 'Ineficiente'
#  'Muito Eficiente' 'Eficiente' 'Eficiente' 'Muito Eficiente' 'Eficiente'
#  'Ineficiente' 'Eficiente' 'Muito Eficiente' 'Ineficiente'
#  'Muito Eficiente' 'Ineficiente' 'Ineficiente' 'Ineficiente'
#  'Muito Eficiente' 'Muito Eficiente' 'Eficiente' 'Ineficiente' 'Eficiente'
#  'Ineficiente' 'Ineficiente' 'Ineficiente' 'Eficiente' 'Eficiente'
#  'Ineficiente' 'Ineficiente']
#
# ---------------------------
#
# Actual Values for Test Set :
#  ['Ineficiente' 'Eficiente' 'Muito Eficiente' 'Eficiente' 'Ineficiente'
#  'Muito Eficiente' 'Eficiente' 'Eficiente' 'Muito Eficiente' 'Eficiente'
#  'Eficiente' 'Eficiente' 'Muito Eficiente' 'Ineficiente' 'Muito Eficiente'
#  'Eficiente' 'Ineficiente' 'Ineficiente' 'Muito Eficiente'
#  'Muito Eficiente' 'Eficiente' 'Ineficiente' 'Eficiente' 'Ineficiente'
#  'Ineficiente' 'Ineficiente' 'Eficiente' 'Eficiente' 'Ineficiente'
#  'Ineficiente']

# %%
#Imprimindo os hyperparâmetros utilizados na criação da Maquina Preditiva Definitiva
classifier
# Out:
# SVC(C=10, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=1e-05, kernel='linear',
#     max_iter=-1, probability=False, random_state=7, shrinking=True, tol=0.001,
#     verbose=False)

# %%
# Calculando a Acurácia da Máquina Preditiva
from sklearn import metrics
print("Prediction Accuracy = ", metrics.accuracy_score(y_test, y_pred))

# Comparando valores Reais com Preditos pela Máquina
print("\nActual vs Predicted  \n------------------------------\n")
error_df = pd.DataFrame({"Actual" : y_test,
                         "Predicted" : y_pred})

error_df.head(5)
# Out:
# Prediction Accuracy =  0.9333333333333333
#
# Actual vs Predicted
# ------------------------------
#             Actual        Predicted
# 0      Ineficiente      Ineficiente
# 1        Eficiente        Eficiente
# 2  Muito Eficiente  Muito Eficiente
# 3        Eficiente        Eficiente
# 4      Ineficiente      Ineficiente

# %%
#Usando a confusion matrix e o classification report para avaliar a Máquina
from sklearn.metrics import confusion_matrix, classification_report

cm = confusion_matrix(y_test,y_pred)
cr = classification_report(y_test, y_pred)

# %%
# Imprimindo a Confusion Matrix e o Classification Report
print(cm)
print(cr)
# Out:
# [[10  2  0]
#  [ 0 11  0]
#  [ 0  0  7]]
#                  precision    recall  f1-score   support
#
#       Eficiente       1.00      0.83      0.91        12
#     Ineficiente       0.85      1.00      0.92        11
# Muito Eficiente       1.00      1.00      1.00         7
#
#        accuracy                           0.93        30
#       macro avg       0.95      0.94      0.94        30
#    weighted avg       0.94      0.93      0.93        30

# %% [markdown]
# # <font color='Black'> **- Criando a Aplicação WEB com a Máquina Preditiva** </font>

# %% [markdown]
# # <font color='Blue'>6° Deploy - Implementando a Maquina Preditiva na WEB</font>

# %% [markdown]
# ### ** Implementação do Sistema de Análise de Eficiência:

# %% [markdown]
# **1°** o sistema fica em nuvem para ser testado pela área ou manutenção observando o status atual da máquina ou equipamento referente a Eficiencia naquele instante :
# *O Teste pode ser realizado na +area com auxilio Tablet,Iphone etc...para auxiliar na tomada de decisão.

# %% [markdown]
# # Fim

# %% [markdown]
# ![alt text](https://miro.medium.com/max/625/1*XBWI6eNVLS_70s1qS46E1w.gif)

# %% [markdown]
# ## Agradeçemos!
